# %%
import numpy as np
import pandas as pd
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
from tqdm import tqdm
# Out:
# /home/narendra/anaconda3/lib/python3.11/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
df= pd.read_excel("Mahindra SKUs Exst.xlsx",sheet_name="Sheet1")

# %%
df_exclude_model=pd.read_excel("all data.xlsx",sheet_name="Exclude_models")
df_brandkey_partype_showonapp=pd.read_excel("all data.xlsx",sheet_name="brand_key")
df_180_min=pd.read_excel("all data.xlsx",sheet_name="180_min")
df_hsn_gst = pd.read_excel("all data.xlsx",sheet_name="hsn_code")
df_varient_key=pd.read_excel("all data.xlsx",sheet_name="varient_key")
df_image_url = pd.read_excel("all data.xlsx",sheet_name="image_url")

# %%
df
# Out:
#       Corrected SKU     Brand                       Name  \
# 0     0303BAU00110N  Mahindra                 Oil Filter
# 1     0303BAU00110N  Mahindra                 Oil Filter
# 2     0303BAU00110N  Mahindra                 Oil Filter
# 3     0303BAU00110N  Mahindra                 Oil Filter
# 4     0303BAU00110N  Mahindra                 Oil Filter
# ...             ...       ...                        ...
# 2687     7701473544  Mahindra  Crankshaft Rear Main Seal
# 2688     7701473544  Mahindra  Crankshaft Rear Main Seal
# 2689     7701473544  Mahindra  Crankshaft Rear Main Seal
# 2690     7701473544  Mahindra  Crankshaft Rear Main Seal
# 2691     7701473544  Mahindra  Crankshaft Rear Main Seal
#
#                              Descrption    MRP Category     Sub Category  \
# 0                    OIL FILTER - MAHLE  171.0  Filters       Oil Filter
# 1                    OIL FILTER - MAHLE  171.0  Filters       Oil Filter
# 2                    OIL FILTER - MAHLE  171.0  Filters       Oil Filter
# 3                    OIL FILTER - MAHLE  171.0  Filters       Oil Filter
# 4                    OIL FILTER - MAHLE  171.0  Filters       Oil Filter
# ...                                 ...    ...      ...              ...
# 2687  COUPLING END CRANKSHAFT SEAL RING    NaN   Engine  Crankshaft Seal
# 2688  COUPLING END CRANKSHAFT SEAL RING    NaN   Engine  Crankshaft Seal
# 2689  COUPLING END CRANKSHAFT SEAL RING    NaN   Engine  Crankshaft Seal
# 2690  COUPLING END CRANKSHAFT SEAL RING    NaN   Engine  Crankshaft Seal
# 2691  COUPLING END CRANKSHAFT SEAL RING    NaN   Engine  Crankshaft Seal
#
#            Class      Make                                          Model  \
# 0     Oil Filter  Mahindra                        BOLERO 1ST GEN 2.5L XLS
# 1     Oil Filter  Mahindra                 BOLERO 1ST GEN 2.5L MDI TC 2WD
# 2     Oil Filter  Mahindra      BOLERO 1ST GEN 2.5L LX GLX SPORTZ 2WD/4WD
# 3     Oil Filter  Mahindra                  BOLERO 1ST GEN 2.5L DI DX 2WD
# 4     Oil Filter  Mahindra  BOLERO 1ST GEN 2.5L LX GLX SPORTZ VFD 2WD/4WD
# ...          ...       ...                                            ...
# 2687         NaN   RENAULT                                LODGY 1.5L JSMW
# 2688         NaN   RENAULT                                LOGAN 1.5L LS0K
# 2689         NaN   RENAULT                                LOGAN 1.5L LS00
# 2690         NaN   RENAULT                                PULSE 1.5L BDMD
# 2691         NaN   RENAULT                                SCALA 1.5L LJMD
#
#                    Year Engine Power (hp) Fuel type             Engine type
# 0     02.2005 - 02.2007  2.5 L    76 h.p.    Diesel                    XD3P
# 1     02.2005 - 02.2007  2.5 L    63 h.p.    Diesel  MDI TC 3200 GEAR DRIVE
# 2     09.2005 - 02.2007  2.5 L    76 h.p.    Diesel                    XD3P
# 3     03.2006 - 09.2011  2.5 L    63 h.p.    Diesel             MDI TC 3200
# 4     03.2006 - 09.2011  2.5 L    76 h.p.    Diesel                    XD3P
# ...                 ...    ...        ...       ...                     ...
# 2687  04.2015 - 12.2019  1.5 L    85 h.p.    Diesel                 K9K-830
# 2688  01.2007 - 12.2011  1.5 L    66 h.p.    Diesel                 K9K-792
# 2689  01.2011 - 12.2011  1.5 L    65 h.p.    Diesel        K9K-790; K9K-794
# 2690  01.2012 - 10.2017  1.5 L    64 h.p.    Diesel                 K9K-422
# 2691  01.2012 - 10.2017  1.5 L    86 h.p.    Diesel                 K9K-424
#
# [2692 rows x 15 columns]

# %%
universal_index=df[(df["Make"]=="UNIVERSAL") | (df["Make"]=="Universal")].index

# %%
universal_index
# Out:
# Int64Index([], dtype='int64')

# %%
universal_data=df.iloc[universal_index]
universal_data
# Out:
# Empty DataFrame
# Columns: [Corrected SKU, Brand, Name, Descrption, MRP, Category, Sub Category, Class, Make, Model, Year, Engine, Power (hp), Fuel type, Engine type]
# Index: []

# %%
df.drop(universal_index,inplace=True)

# %%
df.reset_index(inplace=True)

# %%
df.drop("index",axis=1,inplace=True)

# %%
df.head()
# Out:
#    Corrected SKU     Brand        Name          Descrption    MRP Category  \
# 0  0303BAU00110N  Mahindra  Oil Filter  OIL FILTER - MAHLE  171.0  Filters
# 1  0303BAU00110N  Mahindra  Oil Filter  OIL FILTER - MAHLE  171.0  Filters
# 2  0303BAU00110N  Mahindra  Oil Filter  OIL FILTER - MAHLE  171.0  Filters
# 3  0303BAU00110N  Mahindra  Oil Filter  OIL FILTER - MAHLE  171.0  Filters
# 4  0303BAU00110N  Mahindra  Oil Filter  OIL FILTER - MAHLE  171.0  Filters
#
#   Sub Category       Class      Make  \
# 0   Oil Filter  Oil Filter  Mahindra
# 1   Oil Filter  Oil Filter  Mahindra
# 2   Oil Filter  Oil Filter  Mahindra
# 3   Oil Filter  Oil Filter  Mahindra
# 4   Oil Filter  Oil Filter  Mahindra
#
#                                            Model               Year Engine  \
# 0                        BOLERO 1ST GEN 2.5L XLS  02.2005 - 02.2007  2.5 L
# 1                 BOLERO 1ST GEN 2.5L MDI TC 2WD  02.2005 - 02.2007  2.5 L
# 2      BOLERO 1ST GEN 2.5L LX GLX SPORTZ 2WD/4WD  09.2005 - 02.2007  2.5 L
# 3                  BOLERO 1ST GEN 2.5L DI DX 2WD  03.2006 - 09.2011  2.5 L
# 4  BOLERO 1ST GEN 2.5L LX GLX SPORTZ VFD 2WD/4WD  03.2006 - 09.2011  2.5 L
#
#   Power (hp) Fuel type             Engine type
# 0    76 h.p.    Diesel                    XD3P
# 1    63 h.p.    Diesel  MDI TC 3200 GEAR DRIVE
# 2    76 h.p.    Diesel                    XD3P
# 3    63 h.p.    Diesel             MDI TC 3200
# 4    76 h.p.    Diesel                    XD3P

# %%
df["Power (hp) bracket"] = df["Power (hp)"].apply(lambda x: "("+str(x)+")")

# %%
df["first_set"]=df["Model"]+df["Power (hp) bracket"]+df["Fuel type"]+df["Year"]

# %%
df["productname_brand"]=df["Name"]+"_"+df["Brand"]

# %%
df = df.assign(part_key=None)
df = df.assign(row_key=None)
df = df.assign(variant_key=None)
df = df.assign(brand_key=None)

df = df.assign(part_number=None)
for i in range(len(df)):
    df["part_number"][i] = str(df["Corrected SKU"][i]).strip()
    
df = df.assign(part_name=None)
for i in range(len(df)):
    df["part_name"][i] = str(df["Name"][i]).strip()


df = df.assign(part_description=None)
for i in range(len(df)):
    df["part_description"][i] = str(df["Descrption"][i]).strip()

df=df.assign(part_type=None)

df = df.assign(part_category=None)
for i in range(len(df)):
    df["part_category"][i] = str(df["Category"][i]).strip()


df=df.assign(product_image_url=None)
df=df.assign(unit=0)
df=df.assign(hsn_code=None)
df=df.assign(gst_rate=None)
df["easyecom_sku"] = df["part_number"]

df=df.assign(status=1)
df=df.assign(created_by="Narendra")
df=df.assign(updated_by="Narendra")

df["mrp*100"]=df["MRP"]*100

df["mrp"] = df["mrp*100"]

df["delivery_status"] = "Free Delavery"

df=df.assign(show_on_app=None)
df=df.assign(verified=1)
df=df.assign(delivery_time=None)


df = df.assign(part_sub_category=None)
for i in range(len(df)):
    df["part_sub_category"][i] = str(df["Sub Category"][i]).strip()
# Out:
# /tmp/ipykernel_7611/1342075701.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["part_number"][i] = str(df["Corrected SKU"][i]).strip()
# /tmp/ipykernel_7611/1342075701.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["part_name"][i] = str(df["Name"][i]).strip()
# /tmp/ipykernel_7611/1342075701.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["part_description"][i] = str(df["Descrption"][i]).strip()
# /tmp/ipykernel_7611/1342075701.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["part_category"][i] = str(df["Category"][i]).strip()
# /tmp/ipykernel_7611/1342075701.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["part_sub_category"][i] = str(df["Sub Category"][i]).strip()

# %%
df
# Out:
#       Corrected SKU     Brand                       Name  \
# 0     0303BAU00110N  Mahindra                 Oil Filter
# 1     0303BAU00110N  Mahindra                 Oil Filter
# 2     0303BAU00110N  Mahindra                 Oil Filter
# 3     0303BAU00110N  Mahindra                 Oil Filter
# 4     0303BAU00110N  Mahindra                 Oil Filter
# ...             ...       ...                        ...
# 2687     7701473544  Mahindra  Crankshaft Rear Main Seal
# 2688     7701473544  Mahindra  Crankshaft Rear Main Seal
# 2689     7701473544  Mahindra  Crankshaft Rear Main Seal
# 2690     7701473544  Mahindra  Crankshaft Rear Main Seal
# 2691     7701473544  Mahindra  Crankshaft Rear Main Seal
#
#                              Descrption    MRP Category     Sub Category  \
# 0                    OIL FILTER - MAHLE  171.0  Filters       Oil Filter
# 1                    OIL FILTER - MAHLE  171.0  Filters       Oil Filter
# 2                    OIL FILTER - MAHLE  171.0  Filters       Oil Filter
# 3                    OIL FILTER - MAHLE  171.0  Filters       Oil Filter
# 4                    OIL FILTER - MAHLE  171.0  Filters       Oil Filter
# ...                                 ...    ...      ...              ...
# 2687  COUPLING END CRANKSHAFT SEAL RING    NaN   Engine  Crankshaft Seal
# 2688  COUPLING END CRANKSHAFT SEAL RING    NaN   Engine  Crankshaft Seal
# 2689  COUPLING END CRANKSHAFT SEAL RING    NaN   Engine  Crankshaft Seal
# 2690  COUPLING END CRANKSHAFT SEAL RING    NaN   Engine  Crankshaft Seal
# 2691  COUPLING END CRANKSHAFT SEAL RING    NaN   Engine  Crankshaft Seal
#
#            Class      Make                                          Model  \
# 0     Oil Filter  Mahindra                        BOLERO 1ST GEN 2.5L XLS
# 1     Oil Filter  Mahindra                 BOLERO 1ST GEN 2.5L MDI TC 2WD
# 2     Oil Filter  Mahindra      BOLERO 1ST GEN 2.5L LX GLX SPORTZ 2WD/4WD
# 3     Oil Filter  Mahindra                  BOLERO 1ST GEN 2.5L DI DX 2WD
# 4     Oil Filter  Mahindra  BOLERO 1ST GEN 2.5L LX GLX SPORTZ VFD 2WD/4WD
# ...          ...       ...                                            ...
# 2687         NaN   RENAULT                                LODGY 1.5L JSMW
# 2688         NaN   RENAULT                                LOGAN 1.5L LS0K
# 2689         NaN   RENAULT                                LOGAN 1.5L LS00
# 2690         NaN   RENAULT                                PULSE 1.5L BDMD
# 2691         NaN   RENAULT                                SCALA 1.5L LJMD
#
#       ... status created_by updated_by  mrp*100      mrp delivery_status  \
# 0     ...      1   Narendra   Narendra  17100.0  17100.0   Free Delavery
# 1     ...      1   Narendra   Narendra  17100.0  17100.0   Free Delavery
# 2     ...      1   Narendra   Narendra  17100.0  17100.0   Free Delavery
# 3     ...      1   Narendra   Narendra  17100.0  17100.0   Free Delavery
# 4     ...      1   Narendra   Narendra  17100.0  17100.0   Free Delavery
# ...   ...    ...        ...        ...      ...      ...             ...
# 2687  ...      1   Narendra   Narendra      NaN      NaN   Free Delavery
# 2688  ...      1   Narendra   Narendra      NaN      NaN   Free Delavery
# 2689  ...      1   Narendra   Narendra      NaN      NaN   Free Delavery
# 2690  ...      1   Narendra   Narendra      NaN      NaN   Free Delavery
# 2691  ...      1   Narendra   Narendra      NaN      NaN   Free Delavery
#
#      show_on_app verified delivery_time part_sub_category
# 0           None        1          None        Oil Filter
# 1           None        1          None        Oil Filter
# 2           None        1          None        Oil Filter
# 3           None        1          None        Oil Filter
# 4           None        1          None        Oil Filter
# ...          ...      ...           ...               ...
# 2687        None        1          None   Crankshaft Seal
# 2688        None        1          None   Crankshaft Seal
# 2689        None        1          None   Crankshaft Seal
# 2690        None        1          None   Crankshaft Seal
# 2691        None        1          None   Crankshaft Seal
#
# [2692 rows x 42 columns]

# %%
df_exclude_model
# Out:
#              Make             Model
# 0   ASHOK LEYLAND              DOST
# 1           FORCE         TRAVELLER
# 2        MAHINDRA              ALFA
# 3        MAHINDRA     BOLERO PIK-UP
# 4        MAHINDRA               GIO
# 5        MAHINDRA             JEETO
# 6        MAHINDRA        IMPERIO DC
# 7        MAHINDRA        MAXI TRUCK
# 8        MAHINDRA      MAXX PICK UP
# 9        MAHINDRA  MAXXIMO MINI VAN
# 10       MAHINDRA       SUPRO TRUCK
# 11       MAHINDRA      MAXXIMO PLUS
# 12       MAHINDRA              TREO
# 13       MAHINDRA               ZOR
# 14         MARUTI       SUPER CARRY
# 15        PREMIER         SIGMA Box
# 16           TATA               207
# 17           TATA               ACE
# 18           TATA             MAGIC

# %%
exclude_model_index=[]
for i in range(len(df_exclude_model)):
    ind=df[df.Model.str.contains(str(df_exclude_model["Model"][i]))].index
    for j in ind:
        exclude_model_index.append(j)

# %%
df.drop(exclude_model_index,inplace=True)

# %%
df.reset_index(inplace=True)

# %%
df.drop("index",axis=1,inplace=True)

# %%
df
# Out:
#       Corrected SKU     Brand                       Name  \
# 0     0303BAU00110N  Mahindra                 Oil Filter
# 1     0303BAU00110N  Mahindra                 Oil Filter
# 2     0303BAU00110N  Mahindra                 Oil Filter
# 3     0303BAU00110N  Mahindra                 Oil Filter
# 4     0303BAU00110N  Mahindra                 Oil Filter
# ...             ...       ...                        ...
# 2479     7701473544  Mahindra  Crankshaft Rear Main Seal
# 2480     7701473544  Mahindra  Crankshaft Rear Main Seal
# 2481     7701473544  Mahindra  Crankshaft Rear Main Seal
# 2482     7701473544  Mahindra  Crankshaft Rear Main Seal
# 2483     7701473544  Mahindra  Crankshaft Rear Main Seal
#
#                              Descrption    MRP Category     Sub Category  \
# 0                    OIL FILTER - MAHLE  171.0  Filters       Oil Filter
# 1                    OIL FILTER - MAHLE  171.0  Filters       Oil Filter
# 2                    OIL FILTER - MAHLE  171.0  Filters       Oil Filter
# 3                    OIL FILTER - MAHLE  171.0  Filters       Oil Filter
# 4                    OIL FILTER - MAHLE  171.0  Filters       Oil Filter
# ...                                 ...    ...      ...              ...
# 2479  COUPLING END CRANKSHAFT SEAL RING    NaN   Engine  Crankshaft Seal
# 2480  COUPLING END CRANKSHAFT SEAL RING    NaN   Engine  Crankshaft Seal
# 2481  COUPLING END CRANKSHAFT SEAL RING    NaN   Engine  Crankshaft Seal
# 2482  COUPLING END CRANKSHAFT SEAL RING    NaN   Engine  Crankshaft Seal
# 2483  COUPLING END CRANKSHAFT SEAL RING    NaN   Engine  Crankshaft Seal
#
#            Class      Make                                          Model  \
# 0     Oil Filter  Mahindra                        BOLERO 1ST GEN 2.5L XLS
# 1     Oil Filter  Mahindra                 BOLERO 1ST GEN 2.5L MDI TC 2WD
# 2     Oil Filter  Mahindra      BOLERO 1ST GEN 2.5L LX GLX SPORTZ 2WD/4WD
# 3     Oil Filter  Mahindra                  BOLERO 1ST GEN 2.5L DI DX 2WD
# 4     Oil Filter  Mahindra  BOLERO 1ST GEN 2.5L LX GLX SPORTZ VFD 2WD/4WD
# ...          ...       ...                                            ...
# 2479         NaN   RENAULT                                LODGY 1.5L JSMW
# 2480         NaN   RENAULT                                LOGAN 1.5L LS0K
# 2481         NaN   RENAULT                                LOGAN 1.5L LS00
# 2482         NaN   RENAULT                                PULSE 1.5L BDMD
# 2483         NaN   RENAULT                                SCALA 1.5L LJMD
#
#       ... status created_by updated_by  mrp*100      mrp delivery_status  \
# 0     ...      1   Narendra   Narendra  17100.0  17100.0   Free Delavery
# 1     ...      1   Narendra   Narendra  17100.0  17100.0   Free Delavery
# 2     ...      1   Narendra   Narendra  17100.0  17100.0   Free Delavery
# 3     ...      1   Narendra   Narendra  17100.0  17100.0   Free Delavery
# 4     ...      1   Narendra   Narendra  17100.0  17100.0   Free Delavery
# ...   ...    ...        ...        ...      ...      ...             ...
# 2479  ...      1   Narendra   Narendra      NaN      NaN   Free Delavery
# 2480  ...      1   Narendra   Narendra      NaN      NaN   Free Delavery
# 2481  ...      1   Narendra   Narendra      NaN      NaN   Free Delavery
# 2482  ...      1   Narendra   Narendra      NaN      NaN   Free Delavery
# 2483  ...      1   Narendra   Narendra      NaN      NaN   Free Delavery
#
#      show_on_app verified delivery_time part_sub_category
# 0           None        1          None        Oil Filter
# 1           None        1          None        Oil Filter
# 2           None        1          None        Oil Filter
# 3           None        1          None        Oil Filter
# 4           None        1          None        Oil Filter
# ...          ...      ...           ...               ...
# 2479        None        1          None   Crankshaft Seal
# 2480        None        1          None   Crankshaft Seal
# 2481        None        1          None   Crankshaft Seal
# 2482        None        1          None   Crankshaft Seal
# 2483        None        1          None   Crankshaft Seal
#
# [2484 rows x 42 columns]

# %%
df_brandkey_partype_showonapp
# Out:
#       id           name                         brand_key type  show_on_app
# 0     53      Purolator  3484ac680af6165afc8b35e3736cab67  OES            1
# 1     54          Bosch  ebdeb4a88164633bb71c1d9a0d647f7c  OES            1
# 2     56          Hella  cc6dd726ba70ac8caafc8f22d82758cd  OES            1
# 3     57       Mahindra  5a18cf9ad0a91d1cdde769ac27a288e9  OEM            0
# 4     58  Maruti Suzuki  3dd5a0e87558f673fa4caa008d3ccafa  OEM            1
# ..   ...            ...                               ...  ...          ...
# 792  869         Veturi  db8243ec6bdd2981ecd2360fdb52e3fc  OES            0
# 793  870   Berger Viton  b78821730f48e6d1a1ff7df52c59c4e5  OES            0
# 794  871           Deer  6d3da882c0b6c0bcc33f37e79fd1b251  OES            0
# 795  872         Cromax  34dc6f3fdf869bfe516826140e49d131  OES            0
# 796  873        Nerolac  a27b044d282b8ecf07ad6db1166c1b76  OES            0
#
# [797 rows x 5 columns]

# %%
brand_key_data={}
part_type_data={}
show_on_app_data={}
for i in range(len(df_brandkey_partype_showonapp)):
    brand_key_data[str(df_brandkey_partype_showonapp["name"][i]).lower()]=df_brandkey_partype_showonapp["brand_key"][i]
    part_type_data[str(df_brandkey_partype_showonapp["name"][i]).lower()]=df_brandkey_partype_showonapp["type"][i]
    show_on_app_data[str(df_brandkey_partype_showonapp["name"][i]).lower()]=df_brandkey_partype_showonapp["show_on_app"][i]

# %%
for i in range(len(df)):
    if str(df["Brand"][i]).lower() in brand_key_data:
        df["brand_key"][i]=brand_key_data[str(df["Brand"][i]).lower()]
        df["part_type"][i]=part_type_data[str(df["Brand"][i]).lower()]
        df["show_on_app"][i]=show_on_app_data[str(df["Brand"][i]).lower()]
# Out:
# /tmp/ipykernel_7611/2011477518.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["brand_key"][i]=brand_key_data[str(df["Brand"][i]).lower()]
# /tmp/ipykernel_7611/2011477518.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["part_type"][i]=part_type_data[str(df["Brand"][i]).lower()]
# /tmp/ipykernel_7611/2011477518.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["show_on_app"][i]=show_on_app_data[str(df["Brand"][i]).lower()]

# %%
df
# Out:
#       Corrected SKU     Brand                       Name  \
# 0     0303BAU00110N  Mahindra                 Oil Filter
# 1     0303BAU00110N  Mahindra                 Oil Filter
# 2     0303BAU00110N  Mahindra                 Oil Filter
# 3     0303BAU00110N  Mahindra                 Oil Filter
# 4     0303BAU00110N  Mahindra                 Oil Filter
# ...             ...       ...                        ...
# 2479     7701473544  Mahindra  Crankshaft Rear Main Seal
# 2480     7701473544  Mahindra  Crankshaft Rear Main Seal
# 2481     7701473544  Mahindra  Crankshaft Rear Main Seal
# 2482     7701473544  Mahindra  Crankshaft Rear Main Seal
# 2483     7701473544  Mahindra  Crankshaft Rear Main Seal
#
#                              Descrption    MRP Category     Sub Category  \
# 0                    OIL FILTER - MAHLE  171.0  Filters       Oil Filter
# 1                    OIL FILTER - MAHLE  171.0  Filters       Oil Filter
# 2                    OIL FILTER - MAHLE  171.0  Filters       Oil Filter
# 3                    OIL FILTER - MAHLE  171.0  Filters       Oil Filter
# 4                    OIL FILTER - MAHLE  171.0  Filters       Oil Filter
# ...                                 ...    ...      ...              ...
# 2479  COUPLING END CRANKSHAFT SEAL RING    NaN   Engine  Crankshaft Seal
# 2480  COUPLING END CRANKSHAFT SEAL RING    NaN   Engine  Crankshaft Seal
# 2481  COUPLING END CRANKSHAFT SEAL RING    NaN   Engine  Crankshaft Seal
# 2482  COUPLING END CRANKSHAFT SEAL RING    NaN   Engine  Crankshaft Seal
# 2483  COUPLING END CRANKSHAFT SEAL RING    NaN   Engine  Crankshaft Seal
#
#            Class      Make                                          Model  \
# 0     Oil Filter  Mahindra                        BOLERO 1ST GEN 2.5L XLS
# 1     Oil Filter  Mahindra                 BOLERO 1ST GEN 2.5L MDI TC 2WD
# 2     Oil Filter  Mahindra      BOLERO 1ST GEN 2.5L LX GLX SPORTZ 2WD/4WD
# 3     Oil Filter  Mahindra                  BOLERO 1ST GEN 2.5L DI DX 2WD
# 4     Oil Filter  Mahindra  BOLERO 1ST GEN 2.5L LX GLX SPORTZ VFD 2WD/4WD
# ...          ...       ...                                            ...
# 2479         NaN   RENAULT                                LODGY 1.5L JSMW
# 2480         NaN   RENAULT                                LOGAN 1.5L LS0K
# 2481         NaN   RENAULT                                LOGAN 1.5L LS00
# 2482         NaN   RENAULT                                PULSE 1.5L BDMD
# 2483         NaN   RENAULT                                SCALA 1.5L LJMD
#
#       ... status created_by updated_by  mrp*100      mrp delivery_status  \
# 0     ...      1   Narendra   Narendra  17100.0  17100.0   Free Delavery
# 1     ...      1   Narendra   Narendra  17100.0  17100.0   Free Delavery
# 2     ...      1   Narendra   Narendra  17100.0  17100.0   Free Delavery
# 3     ...      1   Narendra   Narendra  17100.0  17100.0   Free Delavery
# 4     ...      1   Narendra   Narendra  17100.0  17100.0   Free Delavery
# ...   ...    ...        ...        ...      ...      ...             ...
# 2479  ...      1   Narendra   Narendra      NaN      NaN   Free Delavery
# 2480  ...      1   Narendra   Narendra      NaN      NaN   Free Delavery
# 2481  ...      1   Narendra   Narendra      NaN      NaN   Free Delavery
# 2482  ...      1   Narendra   Narendra      NaN      NaN   Free Delavery
# 2483  ...      1   Narendra   Narendra      NaN      NaN   Free Delavery
#
#      show_on_app verified delivery_time part_sub_category
# 0              0        1          None        Oil Filter
# 1              0        1          None        Oil Filter
# 2              0        1          None        Oil Filter
# 3              0        1          None        Oil Filter
# 4              0        1          None        Oil Filter
# ...          ...      ...           ...               ...
# 2479           0        1          None   Crankshaft Seal
# 2480           0        1          None   Crankshaft Seal
# 2481           0        1          None   Crankshaft Seal
# 2482           0        1          None   Crankshaft Seal
# 2483           0        1          None   Crankshaft Seal
#
# [2484 rows x 42 columns]

# %%
list1=[]
for i in range(len(df_180_min)):
    list1.append(df_180_min["Sub Category"][i].lower())

# %%
for i in range(len(df)):
    if str(df["Sub Category"][i].lower()) in list1:
        df["delivery_time"][i]=180
    else:
        df["delivery_time"][i]=90
# Out:
# /tmp/ipykernel_7611/1536158557.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["delivery_time"][i]=180
# /tmp/ipykernel_7611/1536158557.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["delivery_time"][i]=90

# %%
df
# Out:
#       Corrected SKU     Brand                       Name  \
# 0     0303BAU00110N  Mahindra                 Oil Filter
# 1     0303BAU00110N  Mahindra                 Oil Filter
# 2     0303BAU00110N  Mahindra                 Oil Filter
# 3     0303BAU00110N  Mahindra                 Oil Filter
# 4     0303BAU00110N  Mahindra                 Oil Filter
# ...             ...       ...                        ...
# 2479     7701473544  Mahindra  Crankshaft Rear Main Seal
# 2480     7701473544  Mahindra  Crankshaft Rear Main Seal
# 2481     7701473544  Mahindra  Crankshaft Rear Main Seal
# 2482     7701473544  Mahindra  Crankshaft Rear Main Seal
# 2483     7701473544  Mahindra  Crankshaft Rear Main Seal
#
#                              Descrption    MRP Category     Sub Category  \
# 0                    OIL FILTER - MAHLE  171.0  Filters       Oil Filter
# 1                    OIL FILTER - MAHLE  171.0  Filters       Oil Filter
# 2                    OIL FILTER - MAHLE  171.0  Filters       Oil Filter
# 3                    OIL FILTER - MAHLE  171.0  Filters       Oil Filter
# 4                    OIL FILTER - MAHLE  171.0  Filters       Oil Filter
# ...                                 ...    ...      ...              ...
# 2479  COUPLING END CRANKSHAFT SEAL RING    NaN   Engine  Crankshaft Seal
# 2480  COUPLING END CRANKSHAFT SEAL RING    NaN   Engine  Crankshaft Seal
# 2481  COUPLING END CRANKSHAFT SEAL RING    NaN   Engine  Crankshaft Seal
# 2482  COUPLING END CRANKSHAFT SEAL RING    NaN   Engine  Crankshaft Seal
# 2483  COUPLING END CRANKSHAFT SEAL RING    NaN   Engine  Crankshaft Seal
#
#            Class      Make                                          Model  \
# 0     Oil Filter  Mahindra                        BOLERO 1ST GEN 2.5L XLS
# 1     Oil Filter  Mahindra                 BOLERO 1ST GEN 2.5L MDI TC 2WD
# 2     Oil Filter  Mahindra      BOLERO 1ST GEN 2.5L LX GLX SPORTZ 2WD/4WD
# 3     Oil Filter  Mahindra                  BOLERO 1ST GEN 2.5L DI DX 2WD
# 4     Oil Filter  Mahindra  BOLERO 1ST GEN 2.5L LX GLX SPORTZ VFD 2WD/4WD
# ...          ...       ...                                            ...
# 2479         NaN   RENAULT                                LODGY 1.5L JSMW
# 2480         NaN   RENAULT                                LOGAN 1.5L LS0K
# 2481         NaN   RENAULT                                LOGAN 1.5L LS00
# 2482         NaN   RENAULT                                PULSE 1.5L BDMD
# 2483         NaN   RENAULT                                SCALA 1.5L LJMD
#
#       ... status created_by updated_by  mrp*100      mrp delivery_status  \
# 0     ...      1   Narendra   Narendra  17100.0  17100.0   Free Delavery
# 1     ...      1   Narendra   Narendra  17100.0  17100.0   Free Delavery
# 2     ...      1   Narendra   Narendra  17100.0  17100.0   Free Delavery
# 3     ...      1   Narendra   Narendra  17100.0  17100.0   Free Delavery
# 4     ...      1   Narendra   Narendra  17100.0  17100.0   Free Delavery
# ...   ...    ...        ...        ...      ...      ...             ...
# 2479  ...      1   Narendra   Narendra      NaN      NaN   Free Delavery
# 2480  ...      1   Narendra   Narendra      NaN      NaN   Free Delavery
# 2481  ...      1   Narendra   Narendra      NaN      NaN   Free Delavery
# 2482  ...      1   Narendra   Narendra      NaN      NaN   Free Delavery
# 2483  ...      1   Narendra   Narendra      NaN      NaN   Free Delavery
#
#      show_on_app verified delivery_time part_sub_category
# 0              0        1           180        Oil Filter
# 1              0        1           180        Oil Filter
# 2              0        1           180        Oil Filter
# 3              0        1           180        Oil Filter
# 4              0        1           180        Oil Filter
# ...          ...      ...           ...               ...
# 2479           0        1            90   Crankshaft Seal
# 2480           0        1            90   Crankshaft Seal
# 2481           0        1            90   Crankshaft Seal
# 2482           0        1            90   Crankshaft Seal
# 2483           0        1            90   Crankshaft Seal
#
# [2484 rows x 42 columns]

# %%
df_hsn_gst
# Out:
#                  Description  tax_rate  tax_code
# 0          Engine OIL - 5W40      0.18  27101980
# 1         Engine OIL - 10W40      0.18  27101980
# 2         Engine OIL - 15W40      0.18  27101980
# 3                 Oil Filter      0.18  84212300
# 4                 Air Filter      0.18  84213100
# ...                      ...       ...       ...
# 2708        Cowl Vent Louver      0.28  87089900
# 2709   Rear Seat Cushion Pad      0.28  87089900
# 2710              Gas Spring      0.28  87089900
# 2711  Door Handle (External)      0.28  87089900
# 2712              Tail Lamps      0.18  85122010
#
# [2713 rows x 3 columns]

# %%
hsn_code_data={}
gst_code_data={}
for i in range(len(df_hsn_gst)):
    hsn_code_data[df_hsn_gst["Description"][i].lower()]=df_hsn_gst["tax_code"][i]
    gst_code_data[df_hsn_gst["Description"][i].lower()]=df_hsn_gst["tax_rate"][i]

# %%
for i in range(len(df)):
    if df["part_name"][i].lower() in hsn_code_data:
        df["hsn_code"][i]=hsn_code_data[df["part_name"][i].lower()]
        df["gst_rate"][i]=gst_code_data[df["part_name"][i].lower()]
# Out:
# /tmp/ipykernel_7611/2920058019.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["hsn_code"][i]=hsn_code_data[df["part_name"][i].lower()]
# /tmp/ipykernel_7611/2920058019.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["gst_rate"][i]=gst_code_data[df["part_name"][i].lower()]

# %%
image_url_data={}
for i in range(len(df_image_url)):
    image_url_data[str(df_image_url["Partname_brand"][i]).lower()]=df_image_url["url"][i]
for i in range(len(df)):
    if df["productname_brand"][i].lower() in image_url_data:
        df["product_image_url"][i]=image_url_data[df["productname_brand"][i].lower()]
# Out:
# /tmp/ipykernel_7611/3451074549.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["product_image_url"][i]=image_url_data[df["productname_brand"][i].lower()]

# %%
secimage_url_data={}
for i in range(len(df_image_url)):
    secimage_url_data[str(df_image_url["Partname"][i]).lower()]=df_image_url["url.1"][i]
for i in range(len(df)):
    if df["part_name"][i].lower() in secimage_url_data:
        df["product_image_url"][i]=secimage_url_data[df["part_name"][i].lower()]
# Out:
# /tmp/ipykernel_7611/1876206987.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["product_image_url"][i]=secimage_url_data[df["part_name"][i].lower()]

# %%
thimage_url_data={}
for i in range(len(df_image_url)):
    thimage_url_data[str(df_image_url["categoryname"][i]).lower()]=df_image_url["image_url"][i]
for i in range(len(df)):
    if df["part_category"][i].lower() in thimage_url_data:
        df["product_image_url"][i]=thimage_url_data[df["part_category"][i].lower()]
# Out:
# /tmp/ipykernel_7611/3784395138.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["product_image_url"][i]=thimage_url_data[df["part_category"][i].lower()]

# %%
df_varient_key
# Out:
#                                                 Variant  \
# 0      I10 1ST GEN 1.1L(67 h.p.)Petrol09.2007 - 10.2010
# 1     I10 1ST GEN F/L 1.1L(69 h.p.)Petrol08.2010 - 0...
# 2     SANTRO 1ST GEN 1.0L(54 h.p.)Petrol09.1998 - 05...
# 3     SANTRO 1ST GEN 1.1L(58 h.p.)Petrol03.2002 - 05...
# 4     SANTRO XING 2ND GEN 1.1L(62 h.p.)Petrol05.2003...
# ...                                                 ...
# 4526  CIVIC 9TH GEN 2.0L VSN(155 h.p.)(NULL)Petrol01...
# 4527  CIVIC 9TH GEN 2.0L VSNH AT(155 h.p.)(NULL)Petr...
# 4528  CIVIC 9TH GEN 2.0L VSNH(155 h.p.)(NULL)Petrol0...
# 4529  OPTRA MAGNUM 2.0L(124 h.p.)(NULL)Diesel01.2008...
# 4530  OPTRA MAGNUM 1.6L(102.58 h.p.)(NULL)Petrol01.2...
#
#                            variant_key                           row_key
# 0     30854be0121e6bccbc87c2d55c6bc53b  3d19bd2a474cb928f2762665ea8ec6e4
# 1     88735daa1d1277d9e7d961a3df5fcc6f  3d19bd2a474cb928f2762665ea8ec6e4
# 2     4fdd138ab78848ee96e097784128ef6b  36769533bd1f00a1626b6289690c6218
# 3     cf39f4e1093906440d9e3f5e47abf54b  36769533bd1f00a1626b6289690c6218
# 4     812a01be8fb6f19dd9760074aec502d9  36769533bd1f00a1626b6289690c6218
# ...                                ...                               ...
# 4526  9945f7e4944d98bea287136095fae4a7  787ed27b4e554c12c2755af880be2a72
# 4527  880eebea9456927e674bd9f68beab84a  787ed27b4e554c12c2755af880be2a72
# 4528  730d1be5d34599ef148ee90545dca6d7  787ed27b4e554c12c2755af880be2a72
# 4529  3a8c1ca13c574d6a36b691f674e80c67  3b69a3f64271bf0a27d948f298530773
# 4530  47e931998e2eb91e4bce2b10bbfd360a  3b69a3f64271bf0a27d948f298530773
#
# [4531 rows x 3 columns]

# %%
varinet_key_data={}
for i in range(len(df_varient_key)):
    varinet_key_data[str(df_varient_key["Variant"][i]).lower()]=df_varient_key["variant_key"][i]

# %%
varient_key_need = []
for i in range(len(df)):
    if str(df["first_set"][i]).lower() in varinet_key_data:
        df["variant_key"][i]=varinet_key_data[str(df["first_set"][i]).lower()]
    else:
        varient_key_need.append(df["first_set"][i])
# Out:
# /tmp/ipykernel_7611/4187067932.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["variant_key"][i]=varinet_key_data[str(df["first_set"][i]).lower()]

# %%
df
# Out:
#       Corrected SKU     Brand                       Name  \
# 0     0303BAU00110N  Mahindra                 Oil Filter
# 1     0303BAU00110N  Mahindra                 Oil Filter
# 2     0303BAU00110N  Mahindra                 Oil Filter
# 3     0303BAU00110N  Mahindra                 Oil Filter
# 4     0303BAU00110N  Mahindra                 Oil Filter
# ...             ...       ...                        ...
# 2479     7701473544  Mahindra  Crankshaft Rear Main Seal
# 2480     7701473544  Mahindra  Crankshaft Rear Main Seal
# 2481     7701473544  Mahindra  Crankshaft Rear Main Seal
# 2482     7701473544  Mahindra  Crankshaft Rear Main Seal
# 2483     7701473544  Mahindra  Crankshaft Rear Main Seal
#
#                              Descrption    MRP Category     Sub Category  \
# 0                    OIL FILTER - MAHLE  171.0  Filters       Oil Filter
# 1                    OIL FILTER - MAHLE  171.0  Filters       Oil Filter
# 2                    OIL FILTER - MAHLE  171.0  Filters       Oil Filter
# 3                    OIL FILTER - MAHLE  171.0  Filters       Oil Filter
# 4                    OIL FILTER - MAHLE  171.0  Filters       Oil Filter
# ...                                 ...    ...      ...              ...
# 2479  COUPLING END CRANKSHAFT SEAL RING    NaN   Engine  Crankshaft Seal
# 2480  COUPLING END CRANKSHAFT SEAL RING    NaN   Engine  Crankshaft Seal
# 2481  COUPLING END CRANKSHAFT SEAL RING    NaN   Engine  Crankshaft Seal
# 2482  COUPLING END CRANKSHAFT SEAL RING    NaN   Engine  Crankshaft Seal
# 2483  COUPLING END CRANKSHAFT SEAL RING    NaN   Engine  Crankshaft Seal
#
#            Class      Make                                          Model  \
# 0     Oil Filter  Mahindra                        BOLERO 1ST GEN 2.5L XLS
# 1     Oil Filter  Mahindra                 BOLERO 1ST GEN 2.5L MDI TC 2WD
# 2     Oil Filter  Mahindra      BOLERO 1ST GEN 2.5L LX GLX SPORTZ 2WD/4WD
# 3     Oil Filter  Mahindra                  BOLERO 1ST GEN 2.5L DI DX 2WD
# 4     Oil Filter  Mahindra  BOLERO 1ST GEN 2.5L LX GLX SPORTZ VFD 2WD/4WD
# ...          ...       ...                                            ...
# 2479         NaN   RENAULT                                LODGY 1.5L JSMW
# 2480         NaN   RENAULT                                LOGAN 1.5L LS0K
# 2481         NaN   RENAULT                                LOGAN 1.5L LS00
# 2482         NaN   RENAULT                                PULSE 1.5L BDMD
# 2483         NaN   RENAULT                                SCALA 1.5L LJMD
#
#       ... status created_by updated_by  mrp*100      mrp delivery_status  \
# 0     ...      1   Narendra   Narendra  17100.0  17100.0   Free Delavery
# 1     ...      1   Narendra   Narendra  17100.0  17100.0   Free Delavery
# 2     ...      1   Narendra   Narendra  17100.0  17100.0   Free Delavery
# 3     ...      1   Narendra   Narendra  17100.0  17100.0   Free Delavery
# 4     ...      1   Narendra   Narendra  17100.0  17100.0   Free Delavery
# ...   ...    ...        ...        ...      ...      ...             ...
# 2479  ...      1   Narendra   Narendra      NaN      NaN   Free Delavery
# 2480  ...      1   Narendra   Narendra      NaN      NaN   Free Delavery
# 2481  ...      1   Narendra   Narendra      NaN      NaN   Free Delavery
# 2482  ...      1   Narendra   Narendra      NaN      NaN   Free Delavery
# 2483  ...      1   Narendra   Narendra      NaN      NaN   Free Delavery
#
#      show_on_app verified delivery_time part_sub_category
# 0              0        1           180        Oil Filter
# 1              0        1           180        Oil Filter
# 2              0        1           180        Oil Filter
# 3              0        1           180        Oil Filter
# 4              0        1           180        Oil Filter
# ...          ...      ...           ...               ...
# 2479           0        1            90   Crankshaft Seal
# 2480           0        1            90   Crankshaft Seal
# 2481           0        1            90   Crankshaft Seal
# 2482           0        1            90   Crankshaft Seal
# 2483           0        1            90   Crankshaft Seal
#
# [2484 rows x 42 columns]

# %%
unique_list = []
for x in varient_key_need:
        if x not in unique_list:
            unique_list.append(x)

# %%
len(unique_list)
# Out:
# 151

# %%
varinet_need = pd.DataFrame()

# %%
varinet_need["boodmo"] =unique_list

# %%
mat1 = []
mat2 = []
p = []

list1 = varinet_need["boodmo"].tolist()
list2 = df_varient_key['Variant'].tolist()
  
threshold = 80

for i in tqdm(range(len(list1))):
    mat1.append(process.extract(str(list1[i]), list2, limit=1))
varinet_need['matches'] = mat1
# Out:
#  95%|███████████████████████████████████████  | 144/151 [09:46<00:25,  3.61s/it]

# %%
for j in varinet_need['matches']: 
    for k in j: 
        if k[1] > threshold: 
            p.append(k[0])
              
    mat2.append(",".join(p)) 
    p = [] 
varinet_need['matches'] = mat2

# %%
varinet_need=varinet_need.assign(varient_key=None)

# %%
varient_dic={}
for i in range(len(df_varient_key)):
    varient_dic[df_varient_key["Variant"][i]]=df_varient_key["variant_key"][i]

# %%
for i in range(len(varinet_need)):
    if varinet_need["matches"][i] in varient_dic:
        varinet_need["varient_key"][i]=varient_dic[varinet_need["matches"][i]]

# %%
varinet_need
# Out:
# Empty DataFrame
# Columns: [boodmo, matches, varient_key]
# Index: []

# %%
with pd.ExcelWriter("Starke SKUs Exst.xlsx", mode="a", engine="openpyxl") as writer:
    df.to_excel(writer,sheet_name="clean_data")
    universal_data.to_excel(writer,sheet_name="universal_data")
    varinet_need.to_excel(writer,sheet_name="varient_key_need")
    df_varient_key.to_excel(writer,sheet_name="varient&row_key_data")
